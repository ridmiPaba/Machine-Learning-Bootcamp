# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv('/Users/prabhavihemachandra/ML bootcamp/DATA/fake_reg.csv')

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
X= df[['feature1','feature2']].values
y= df['price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (700, 2)

# %%
X_test.shape
# Out:
# (300, 2)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
#help(MinMaxScaler)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train =  scaler.transform(X_train)

# %%
X_test =scaler.transform(X_test)

# %%
X_train
# Out:
# array([[0.22179862, 0.55212838],
#        [0.34106018, 0.45061693],
#        [0.44187649, 0.6432228 ],
#        ...,
#        [0.4679684 , 0.12119512],
#        [0.51313398, 0.51308096],
#        [0.51079305, 0.26371433]], shape=(700, 2))

# %%
X_train.min()
# Out:
# np.float64(0.0)

# %%
X_train.max()
# Out:
# np.float64(1.0)
